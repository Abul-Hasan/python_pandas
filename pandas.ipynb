# %%
import pandas as pd

# %%
import numpy as np

# %%
#pip install --upgrade pandas

# %%
df=pd.DataFrame({'s1':s1,'s2':s2})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ba6fd6fdb4c4> in <module>
# ----> 1 df=pd.DataFrame({'s1':s1,'s2':s2})
#       2 df
#
# NameError: name 's1' is not defined

# %%
import pandas as pd
titanic=pd.read_csv('https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/titanic-train.csv.txt',index_col='PassengerId')

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic[:4]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic.fillna({'age':29.6,'Embarked':'s'},inplace=True)

# %%
titanic.Age.isnull()
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889     True
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic.Age.isnull()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
titanic[titanic.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic.Age>60
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic.Age>60]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 34                  0       2                      Wheadon, Mr. Edward H
# 55                  0       1             Ostby, Mr. Engelhart Cornelius
# 97                  0       1                  Goldschmidt, Mr. George B
# 117                 0       3                       Connors, Mr. Patrick
# 171                 0       1                  Van der hoef, Mr. Wyckoff
# 253                 0       1                  Stead, Mr. William Thomas
# 276                 1       1          Andrews, Miss. Kornelia Theodosia
# 281                 0       3                           Duane, Mr. Frank
# 327                 0       3                  Nysveen, Mr. Johan Hansen
# 439                 0       1                          Fortune, Mr. Mark
# 457                 0       1                  Millet, Mr. Francis Davis
# 484                 1       3                     Turkula, Mrs. (Hedwig)
# ...

# %%
df=titanic[titanic.Age>10]

# %%
res=df.Survived

# %%
res.value_counts()
# Out:
# 0    398
# 1    252
# Name: Survived, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    891 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
population_info=pd.read_csv('https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/gapminder-FiveYearData.csv')

# %%
population_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# year         1704 non-null int64
# pop          1704 non-null float64
# continent    1704 non-null object
# lifeExp      1704 non-null float64
# gdpPercap    1704 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
population_info.sample(10)
# Out:
#             country  year          pop continent  lifeExp     gdpPercap
# 1394        Somalia  1962    3080153.0    Africa   36.981   1369.488336
# 784         Jamaica  1972    1997616.0  Americas   69.000   7433.889293
# 739            Iraq  1987   16543189.0      Asia   65.044  11643.572680
# 1615  United States  1987  242803533.0  Americas   75.020  29884.350410
# 771           Italy  1967   52667100.0    Europe   71.060  10022.401310
# 363   Cote d'Ivoire  1967    4744870.0    Africa   47.350   2052.050473
# 123           Benin  1967    2427334.0    Africa   44.885   1035.831411
# 685         Iceland  1957     165110.0    Europe   73.470   9244.001412
# 1636      Venezuela  1972   11515649.0  Americas   65.712  10505.259660
# 167        Botswana  2007    1639131.0    Africa   50.728  12569.851770

# %%
population_info.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df_asia=population_info[population_info.continent == 'Asia']

# %%
df_europe=population_info[population_info.continent == 'Europe']

# %%
df_Africa=population_info[population_info.continent == 'Africa']

# %%
df_america=population_info[population_info.continent == 'America']

# %%
df_oceania=population_info[population_info.continent == 'Oceania']

# %%
df_asia.to_csv('asia_data.csv')

# %%
df_europe.to_csv('europe_data.csv')

# %%
df_asia_data= pd.read_csv('asia_data.csv',index_col='Unnamed: 0')

# %%
df_europe_data= pd.read_csv('europe_data.csv',index_col='Unnamed: 0')

# %%
df_asia_europe= pd.concat([df_asia_data,df_europe_data])

# %%
df_asia_europe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 0 to 1607
# Data columns (total 6 columns):
# country      756 non-null object
# year         756 non-null int64
# pop          756 non-null float64
# continent    756 non-null object
# lifeExp      756 non-null float64
# gdpPercap    756 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 41.3+ KB

# %%
df_asia_europe.tail()
# Out:
#              country  year         pop continent  lifeExp    gdpPercap
# 1603  United Kingdom  1987  56981620.0    Europe   75.007  21664.78767
# 1604  United Kingdom  1992  57866349.0    Europe   76.420  22705.09254
# 1605  United Kingdom  1997  58808266.0    Europe   77.218  26074.53136
# 1606  United Kingdom  2002  59912431.0    Europe   78.471  29478.99919
# 1607  United Kingdom  2007  60776238.0    Europe   79.425  33203.26128

# %%
df_continent_info =pd.DataFrame({'continent':population_info.continent.unique(),'Description':['xyz','abc','def','jkl','ikl']})

# %%
df_continent_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
# continent      5 non-null object
# Description    5 non-null object
# dtypes: object(2)
# memory usage: 208.0+ bytes

# %%
pd.merge(population_info,df_continent_info,on='continent')
# Out:
#           country  year         pop continent  lifeExp     gdpPercap  \
# 0     Afghanistan  1952   8425333.0      Asia   28.801    779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332    820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997    853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020    836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088    739.981106
# ...           ...   ...         ...       ...      ...           ...
# 1699  New Zealand  1987   3317166.0   Oceania   74.320  19007.191290
# 1700  New Zealand  1992   3437674.0   Oceania   76.330  18363.324940
# 1701  New Zealand  1997   3676187.0   Oceania   77.550  21050.413770
# 1702  New Zealand  2002   3908037.0   Oceania   79.110  23189.801350
# 1703  New Zealand  2007   4115771.0   Oceania   80.204  25185.009110
#
#      Description
# 0            xyz
# 1            xyz
# 2            xyz
# 3            xyz
# 4            xyz
# ...          ...
# ...

# %%
emp_data=pd.read_csv('https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')

# %%
emp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
emp_data.sales.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
emp_data.rename(columns={'sales':'department'},inplace=True)

# %%
emp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# department               14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
population_info.gdpPercap.max()
# Out:
# 113523.1329

# %%
df_asia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 396 entries, 0 to 1679
# Data columns (total 6 columns):
# country      396 non-null object
# year         396 non-null int64
# pop          396 non-null float64
# continent    396 non-null object
# lifeExp      396 non-null float64
# gdpPercap    396 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 21.7+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-c2d79e262a48> in <module>
# ----> 1 print(data.loc[gdpPercap:])
#
# NameError: name 'data' is not defined
